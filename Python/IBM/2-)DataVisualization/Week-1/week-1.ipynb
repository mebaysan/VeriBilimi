# %%
import seaborn as sns
import pandas as np
import matplotlib.pyplot as plt

# %%
plt.plot(5,5,'o') # x = 5, y = 5
plt.show() # plot'u göster

# %%
plt.xlabel('X') # x eksen adı
plt.ylabel('Y') # y eksen adı
plt.title('Title') # plot başlığı
plt.show()

# %%
df = sns.load_dataset('tips')

# %%
df['tip'].plot(kind='line')
plt.title('Total Bill Line Plot')
plt.xlabel('Total Bills')
plt.ylabel('Total Bill Count')
plt.show()
